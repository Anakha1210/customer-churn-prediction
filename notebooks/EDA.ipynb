# %%
import pandas as pd

df = pd.read_csv(r"c:\Users\anakh\Documents\churn\customer-churn-prediction\data\telco_churn.csv")

#print(df.head())
#print(df.info())
#print(df.describe())
# Remove columns with more than 30% missing data
#df_cleaned = df.dropna(axis=1, thresh=int(0.7 * len(df)))
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Churn', data=df)

plt.show()
plt.show()
